# %%
from IPython.display import Audio, Image, YouTubeVideo

# %% [markdown]
# # LESSON 1: Talking PyTorch with Soumith Chintala
#
# ## CHAPTER 1: Origins of PyTorch

# %%
id = '0eLXNFv6aT8'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 2: Debugging and Designing PyTorch

# %%
id = 'Nn8140ECzPU'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 3: From Research to Production

# %%
id = 'eCysOAw8azs'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 4: Hybrid Frontend

# %%
id = 'J4z-P8yUZu4'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 5: Cutting-edge Applications in PyTorch

# %%
id = 's8p6vqOubqw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 6: User Needs and Adding Features

# %%
id = '7HH65_c7Acw'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 7: PyTorch and the Facebook Product

# %%
id = 'TjVveb0iVrA'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 8: The Future of PyTorch

# %%
id = 'vfCg3FoOjE4'
YouTubeVideo(id=id, width=600)

# %% [markdown]
# ## CHAPTER 9: Learning More in AI

# %%
id = 'NMItGw0GFGM'
YouTubeVideo(id=id, width=600)
